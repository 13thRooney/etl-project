# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "Resources/Univ_Info.csv"
univ_info_df = pd.read_csv(csv_file)
univ_info_df.head()
# Out:
#    UnitID                                   Institution_Name  \
# 0  240985  \tEducational Technical College-Recinto de Bay...
# 1  177834            A T Still University of Health Sciences
# 2  180203                             Aaniiih Nakoda College
# 3  459523                                 ABC Beauty Academy
# 4  485500                                    ABCO Technology
#
#    Institution_size_category  \
# 0                          1
# 1                          2
# 2                          1
# 3                          1
# 4                          1
#
#                             Institution_entity_name Institution_name_alias  \
# 0  Educational Technical College-Recinto de Bayamon                    NaN
# 1           A T Still University of Health Sciences                    NaN
# 2                            Aaniiih Nakoda College                    NaN
# 3                                ABC Beauty Academy                    NaN
# 4                                   ABCO Technology                    NaN
#
#   City_location                           Address State         Zip
# 0       Bayamon              1685 CARR #2 KL 11.2    PR         959
# 1    Kirksville                   800 W Jefferson    MO       63501
# 2        Harlem       269 Blackfeet Avenue Agency    MT       59526
# 3    Richardson               2109 Buckingham Rd.    TX       75081
# 4     Inglewood  11222 S. La Cienega Blvd Ste 588    CA  90304-1551

# %%
csv_file = "Resources/Labels.csv"
labels_df = pd.read_csv(csv_file)
labels_df.head()
# Out:
#    Value        ValueLabel
# 0      1       Under 1,000
# 1      2     1,000 - 4,999
# 2      3     5,000 - 9,999
# 3      4   10,000 - 19,999
# 4      5  20,000 and above

# %%
csv_file = "Resources/Univ_Admission_Data_2017.csv"
univ_admission_data_2017_df = pd.read_csv(csv_file)
univ_admission_data_2017_df.head()
# Out:
#    UnitID                                   Institution Name  Grand total  \
# 0  240985  \tEducational Technical College-Recinto de Bay...        383.0
# 1  177834            A T Still University of Health Sciences          NaN
# 2  180203                             Aaniiih Nakoda College        122.0
# 3  459523                                 ABC Beauty Academy          NaN
# 4  485500                                    ABCO Technology         50.0
#
#    Total men  Total women
# 0      133.0        250.0
# 1        NaN          NaN
# 2       52.0         70.0
# 3        NaN          NaN
# 4       45.0          5.0

# %% [markdown]
# ### Clean DataFrame

# %%
labels_df = labels_df.rename(columns={"Value": "value_id","ValueLabel":"value_label" })
labels_df
# Out:
#    value_id       value_label
# 0         1       Under 1,000
# 1         2     1,000 - 4,999
# 2         3     5,000 - 9,999
# 3         4   10,000 - 19,999
# 4         5  20,000 and above

# %%
univ_info_df = univ_info_df.rename(columns={"UnitID":"unit_id",
                                            "Institution_Name":"institution_name",
                                            "Institution_size_category":"institution_size_category",
                                            "Institution_entity_name": "institution_entity_name",
                                            "Institution_name_alias": "institution_name_alias",
                                            "City_location":"city_location",
                                            "Address":"address",
                                            "State":"state",
                                            "Zip" : "zip"
                                           }
                                  )
univ_info_df.head()
# Out:
#    unit_id                                   institution_name  \
# 0   240985  \tEducational Technical College-Recinto de Bay...
# 1   177834            A T Still University of Health Sciences
# 2   180203                             Aaniiih Nakoda College
# 3   459523                                 ABC Beauty Academy
# 4   485500                                    ABCO Technology
#
#    institution_size_category  \
# 0                          1
# 1                          2
# 2                          1
# 3                          1
# 4                          1
#
#                             institution_entity_name institution_name_alias  \
# 0  Educational Technical College-Recinto de Bayamon                    NaN
# 1           A T Still University of Health Sciences                    NaN
# 2                            Aaniiih Nakoda College                    NaN
# 3                                ABC Beauty Academy                    NaN
# 4                                   ABCO Technology                    NaN
#
#   city_location                           address state         zip
# 0       Bayamon              1685 CARR #2 KL 11.2    PR         959
# 1    Kirksville                   800 W Jefferson    MO       63501
# 2        Harlem       269 Blackfeet Avenue Agency    MT       59526
# 3    Richardson               2109 Buckingham Rd.    TX       75081
# 4     Inglewood  11222 S. La Cienega Blvd Ste 588    CA  90304-1551

# %%
univ_admission_data_2017_df = univ_admission_data_2017_df.rename(columns={"UnitID":"unit_id",
                                                                          "Institution Name": "institution_name",
                                                                          "Grand total":"total_2017",
                                                                          "Total men":"total_men_2017",
                                                                          "Total women":"total_women_2017"
                                                                           }
                                                                  )
univ_admission_data_2017_df.head()
# Out:
#    unit_id                                   institution_name  total_2017  \
# 0   240985  \tEducational Technical College-Recinto de Bay...       383.0
# 1   177834            A T Still University of Health Sciences         NaN
# 2   180203                             Aaniiih Nakoda College       122.0
# 3   459523                                 ABC Beauty Academy         NaN
# 4   485500                                    ABCO Technology        50.0
#
#    total_men_2017  total_women_2017
# 0           133.0             250.0
# 1             NaN               NaN
# 2            52.0              70.0
# 3             NaN               NaN
# 4            45.0               5.0

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/ETL_Univ_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['labels', 'univ_info', 'univ_admission_data_2017']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
labels_df.to_sql(name='labels', con=engine, if_exists='append', index=False)

# %%
univ_info_df.to_sql(name='univ_info', con=engine, if_exists='append', index=False)

# %%
univ_admission_data_2017_df.to_sql(name='univ_admission_data_2017', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the table

# %%
pd.read_sql_query('select * from labels', con=engine).head()
# Out:
#    value_id       value_label
# 0         1       Under 1,000
# 1         2     1,000 - 4,999
# 2         3     5,000 - 9,999
# 3         4   10,000 - 19,999
# 4         5  20,000 and above

# %%
pd.read_sql_query('select * from univ_info', con=engine).head()
# Out:
#    unit_id                                   institution_name  \
# 0   240985  \tEducational Technical College-Recinto de Bay...
# 1   177834            A T Still University of Health Sciences
# 2   180203                             Aaniiih Nakoda College
# 3   459523                                 ABC Beauty Academy
# 4   485500                                    ABCO Technology
#
#    institution_size_category  \
# 0                          1
# 1                          2
# 2                          1
# 3                          1
# 4                          1
#
#                             institution_entity_name institution_name_alias  \
# 0  Educational Technical College-Recinto de Bayamon                   None
# 1           A T Still University of Health Sciences                   None
# 2                            Aaniiih Nakoda College                   None
# 3                                ABC Beauty Academy                   None
# 4                                   ABCO Technology                   None
#
#   city_location                           address state         zip
# 0       Bayamon              1685 CARR #2 KL 11.2    PR         959
# 1    Kirksville                   800 W Jefferson    MO       63501
# 2        Harlem       269 Blackfeet Avenue Agency    MT       59526
# 3    Richardson               2109 Buckingham Rd.    TX       75081
# 4     Inglewood  11222 S. La Cienega Blvd Ste 588    CA  90304-1551

# %%
pd.read_sql_query('select * from univ_admission_data_2017', con=engine).head()
# Out:
#    unit_id                                   institution_name  total_2017  \
# 0   240985  \tEducational Technical College-Recinto de Bay...       383.0
# 1   177834            A T Still University of Health Sciences         NaN
# 2   180203                             Aaniiih Nakoda College       122.0
# 3   459523                                 ABC Beauty Academy         NaN
# 4   485500                                    ABCO Technology        50.0
#
#    total_men_2017  total_women_2017
# 0           133.0             250.0
# 1             NaN               NaN
# 2            52.0              70.0
# 3             NaN               NaN
# 4            45.0               5.0

# %% [markdown]
# # Joins

# %%
joined_df_1 = pd.merge(univ_admission_data_2017_df, univ_info_df,on='unit_id')
joined_df_1.head()
# Out:
#    unit_id                                 institution_name_x  total_2017  \
# 0   240985  \tEducational Technical College-Recinto de Bay...       383.0
# 1   177834            A T Still University of Health Sciences         NaN
# 2   180203                             Aaniiih Nakoda College       122.0
# 3   459523                                 ABC Beauty Academy         NaN
# 4   485500                                    ABCO Technology        50.0
#
#    total_men_2017  total_women_2017  \
# 0           133.0             250.0
# 1             NaN               NaN
# 2            52.0              70.0
# 3             NaN               NaN
# 4            45.0               5.0
#
#                                   institution_name_y  \
# 0  \tEducational Technical College-Recinto de Bay...
# 1            A T Still University of Health Sciences
# 2                             Aaniiih Nakoda College
# 3                                 ABC Beauty Academy
# 4                                    ABCO Technology
#
#    institution_size_category  \
# 0                          1
# 1                          2
# 2                          1
# 3                          1
# 4                          1
#
#                             institution_entity_name institution_name_alias  \
# 0  Educational Technical College-Recinto de Bayamon                    NaN
# 1           A T Still University of Health Sciences                    NaN
# 2                            Aaniiih Nakoda College                    NaN
# 3                                ABC Beauty Academy                    NaN
# 4                                   ABCO Technology                    NaN
#
#   city_location                           address state         zip
# 0       Bayamon              1685 CARR #2 KL 11.2    PR         959
# 1    Kirksville                   800 W Jefferson    MO       63501
# 2        Harlem       269 Blackfeet Avenue Agency    MT       59526
# 3    Richardson               2109 Buckingham Rd.    TX       75081
# 4     Inglewood  11222 S. La Cienega Blvd Ste 588    CA  90304-1551

# %%
joined_df_2 = pd.merge(joined_df_1,labels_df, left_on='institution_size_category', right_on='value_id')
joined_df_2.head()
# Out:
#    unit_id                                 institution_name_x  total_2017  \
# 0   240985  \tEducational Technical College-Recinto de Bay...       383.0
# 1   180203                             Aaniiih Nakoda College       122.0
# 2   459523                                 ABC Beauty Academy         NaN
# 3   485500                                    ABCO Technology        50.0
# 4   461892                                   Abcott Institute       151.0
#
#    total_men_2017  total_women_2017  \
# 0           133.0             250.0
# 1            52.0              70.0
# 2             NaN               NaN
# 3            45.0               5.0
# 4            10.0             141.0
#
#                                   institution_name_y  \
# 0  \tEducational Technical College-Recinto de Bay...
# 1                             Aaniiih Nakoda College
# 2                                 ABC Beauty Academy
# 3                                    ABCO Technology
# 4                                   Abcott Institute
#
#    institution_size_category  \
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1
#
#                             institution_entity_name institution_name_alias  \
# 0  Educational Technical College-Recinto de Bayamon                    NaN
# 1                            Aaniiih Nakoda College                    NaN
# 2                                ABC Beauty Academy                    NaN
# 3                                   ABCO Technology                    NaN
# 4                                  Abcott Institute                    NaN
#
#   city_location                           address state         zip  value_id  \
# 0       Bayamon              1685 CARR #2 KL 11.2    PR         959         1
# 1        Harlem       269 Blackfeet Avenue Agency    MT       59526         1
# 2    Richardson               2109 Buckingham Rd.    TX       75081         1
# 3     Inglewood  11222 S. La Cienega Blvd Ste 588    CA  90304-1551         1
# 4    Southfield  16250 Northland Drive  Suite 205    MI  48075-5227         1
#
#    value_label
# 0  Under 1,000
# 1  Under 1,000
# 2  Under 1,000
# 3  Under 1,000
# 4  Under 1,000

# %%
df_grp = joined_df_2.groupby(['value_id']).mean()
df_grp
# Out:
#                 unit_id    total_2017  total_men_2017  total_women_2017  \
# value_id
# 1         337971.303037    224.246009       79.784873        144.461136
# 2         207170.854331   2185.100472      912.447067       1272.653405
# 3         193189.492032   6279.824701     2677.165339       3602.659363
# 4         190680.550432  12086.731214     5381.505780       6705.225434
# 5         181047.099548  26844.669683    12337.149321      14507.520362
#
#           institution_size_category
# value_id
# 1                               1.0
# 2                               2.0
# 3                               3.0
# 4                               4.0
# 5                               5.0

# %%
df_grp['percentage_women'] = 100*df_grp['total_women_2017'] / df_grp['total_2017']
df_grp.head()
# Out:
#                 unit_id    total_2017  total_men_2017  total_women_2017  \
# value_id
# 1         337971.303037    224.246009       79.784873        144.461136
# 2         207170.854331   2185.100472      912.447067       1272.653405
# 3         193189.492032   6279.824701     2677.165339       3602.659363
# 4         190680.550432  12086.731214     5381.505780       6705.225434
# 5         181047.099548  26844.669683    12337.149321      14507.520362
#
#           institution_size_category  percentage_women
# value_id
# 1                               1.0         64.420828
# 2                               2.0         58.242329
# 3                               3.0         57.368789
# 4                               4.0         55.475921
# 5                               5.0         54.042462
